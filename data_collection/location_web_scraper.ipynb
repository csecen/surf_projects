# %%
import requests
import csv
import pandas as pd
import re

# imports for webscraping
from bs4 import BeautifulSoup, Comment
import folium
import numpy as np

# %%
def parse_regions(soup, breaks):
    spots_list = soup.find('div', attrs={'class':'block spot-list'})
    
    if spots_list:
        spots = spots_list.findAll('a', attrs={'class':'country'})
        for spot in spots:
            url = spot.attrs['href']
            req = requests.get(url)
            local_soup = BeautifulSoup(req.content, 'html.parser')
            found_spots = parse_regions(local_soup, breaks)
            breaks.extend(found_spots)
    else:
        try:
            regional_spots = soup.find('table', attrs={'class':'spotTable'}).findAll('a')
            return regional_spots
        except AttributeError as e:
            return []
    
    return []

# %%
url = 'https://surfing-waves.com/atlas.html'
req = requests.get(url)   # send request to the starting url

soup = BeautifulSoup(req.content, 'html.parser')

# %%
breaks = []
parse_regions(soup, breaks)
# Out:
# []

# %%
data = []
for b in breaks:
    surl = b.attrs['href']
    sreq = requests.get(surl)
    ssoup = BeautifulSoup(sreq.content, 'html.parser')

    country = re.search(r'\/atlas\/\w+\/(\w+)', surl).group(1)
    
    latlong = re.search(r'=(-?\d+\.\d+),(-?\d+\.\d+)', ssoup.find('div', attrs={'class':'map big_map responsive_map'}).iframe.attrs['src'])
    lat = latlong.group(1)
    long = latlong.group(2)
    
    dets = ssoup.find('table', attrs={'class':'spot-details'})
    wave_type = dets.findAll('td')[1].text
    direction = dets.findAll('td')[2].text
    bottom = dets.findAll('td')[3].text
    difficulty = dets.findAll('td')[4].text
    
    data.append([country, b.text, lat, long, wave_type, direction, bottom, difficulty])
    # coords.append((country.text, spot.text, lat, long))

# %%
df = pd.DataFrame(np.array(data),
                   columns=['Country', 'Break', 'Lat', 'Long', 'Wave_type', 'Direction', 'Bottom', 'Difficulty'])
df.to_csv('surf_breaks.csv', index=False)

# %%
df.head()
# Out:
#       Country              Break                 Lat               Long  \
# 0       ghana        Busua Beach    4.80294370651245  -1.92466735839844
# 1       ghana          The Point    5.49376869201660  -0.36616912484169
# 2       ghana             Till's    5.41222715377808  -0.46760559082031
# 3       ghana  White Sands Point    5.41842174530029  -0.46181201934814
# 4  madagascar         Flameballs  -23.64441871643066  43.57177734375000
#
#      Wave_type     Direction       Bottom           Difficulty
# 0  Beach break  Right & left         Sand            Beginners
# 1  Point break  Right & left  Sand & Rock  Intermediate surfer
# 2  Beach break  Right & left         Sand  Intermediate surfer
# 3  Point break         Right  Sand & Rock      Advanced surfer
# 4   Reef break          Left     Boulders      Advanced surfer

# %%
# Make an empty map
m = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=3)

for i in range(len(df)):
    folium.Marker(
        location=[df.iloc[i]['Lat'], df.iloc[i]['Long']],
        popup=df.iloc[i]['Break'],
    ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca22230e3ff973079428542311aee843 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca22230e3ff973079428542311aee843&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca22230e3ff973079428542311aee843 = L.map(
#                 &quot;map_ca22230e3ff973079428542311aee843&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1f4b61cfa5cfd50191f1c999b475273 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c1f4b61cfa5cfd50191f1c999b475273.addTo(map_ca22230e3ff973079428542311aee843);
#
#
#             var marker_fc839afcc839d9393ec522acdce8b067 = L.marker(
#                 [4.80294370651245, -1.92466735839844],
#                 {}
#             ).addTo(map_ca22230e3ff973079428542311aee843);
#
#
#         var popup_ae1c2a036947514dd101f9d709180913 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cef5e9394b72700033310efd63549b17 = $(`&lt;div id=&quot;html_cef5e9394b72700033310efd63549b17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Busua Beach&lt;/div&gt;`)[0];
#                 popup_ae1c2a036947514dd101f9d709180913.setContent(html_cef5e9394b72700033310efd63549b17);
#
#
#
#         marker_fc839afcc839d9393ec522acdce8b067.bindPopup(popup_ae1c2a036947514dd101f9d709180913)
#         ;
#
#
#
#
#             var marker_867050d9d2163715b6d5039885b0697c = L.marker(
#                 [5.4937686920166, -0.36616912484169],
#                 {}
#             ).addTo(map_ca22230e3ff973079428542311aee843);
#
#
#         var popup_497b23f1ee157db589864562fd366e08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44687c0c60c4250e0c1bd378ff75a00a = $(`&lt;div id=&quot;html_44687c0c60c4250e0c1bd378ff75a00a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Point&lt;/div&gt;`)[0];
#                 popup_497b23f1ee157db589864562fd366e08.setContent(html_44687c0c60c4250e0c1bd378ff75a00a);
#
#
#
#         marker_867050d9d2163715b6d5039885b0697c.bindPopup(popup_497b23f1ee157db589864562fd366e08)
#         ;
#
#
#
#
#             var marker_3099948cd2779826080073d5ee6c934f = L.marker(
#                 [5.41222715377808, -0.46760559082031],
#                 {}
#             ).addTo(map_ca22230e3ff973079428542311aee843);
#
#
#         var popup_2cd2e00afd66b976ddb2fb63815849e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bd96e1c3173c4564f84069971e00702 = $(`&lt;div id=&quot;html_1bd96e1c3173c4564f84069971e00702&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Till&#x27;s&lt;/div&gt;`)[0];
#                 popup_2cd2e00afd66b976ddb2fb63815849e1.setContent(html_1bd96e1c3173c4564f84069971e00702);
#
#
#
#         marker_3099948cd2779826080073d5ee6c934f.bindPopup(popup_2cd2e00afd66b976ddb2fb63815849e1)
#         ;
#
#
#
#
#             var marker_2a786ce2c40f8393bc69773223e0ef43 = L.marker(
#                 [5.41842174530029, -0.46181201934814],
#                 {}
#             ).addTo(map_ca22230e3ff973079428542311aee843);
#
#
#         var popup_bc9433b5a6e70375ac153f626ce6fda7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5417581bf2f430bc2861081ef5105701 = $(`&lt;div id=&quot;html_5417581bf2f430bc2861081ef5105701&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;White Sands Point&lt;/div&gt;`)[0];
#                 popup_bc9433b5a6e70375ac153f626ce6fda7.setContent(html_5417581bf2f430bc2861081ef5105701);
#
#
#
#         marker_2a786ce2c40f8393bc69773223e0ef43.bindPopup(popup_bc9433b5a6e70375ac153f626ce6fda7)
#         ;
#
#
#
#
#             var marker_669a3e34551aa448a3828bb843192c83 = L.marker(
#                 [-23.64441871643066, 43.57177734375],
#                 {}
#             ).addTo(map_ca22230e3ff973079428542311aee843);
#
#
#         var popup_8ccdb82aac4aa42fc25764e382cf90c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8eb543c1a79b16f34cb642f4cc22cdfa = $(`&lt;div id=&quot;html_8eb543c1a79b16f34cb642f4cc22cdfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Flameballs&lt;/div&gt;`)[0];
#                 popup_8ccdb82aac4aa42fc25764e382cf90c5.setContent(html_8eb543c1a79b16f34cb642f4cc22cdfa);
#
#
#
#         marker_669a3e34551aa448a3828bb843192c83.bindPopup(popup_8ccdb82aac4aa42fc25764e382cf90c5)
#         ;
#
#
#
#
#             var marker_6dda2b8603b1728ba64e220b3a40dffd = L.marker(
#                 [-25.43071174621582, 44.93373870849609],

# %%
surl = spots[0].attrs['href']
sreq = requests.get(surl)
ssoup = BeautifulSoup(sreq.content, 'html.parser')

# %%
dets = ssoup.find('table', attrs={'class':'spot-details'})

# %%
dets.findAll('td')
# Out:
# [<td>2</td>,
#  <td>Beach break</td>,
#  <td>Right &amp; left</td>,
#  <td>Sand</td>,
#  <td>Beginners</td>,
#  <td>Empty</td>,
#  <td>none</td>]

# %%
continents = soup.find('div', attrs={'class':'block spot-list'}).findAll('a', attrs={'class':'continent'})
countries = soup.find('div', attrs={'class':'block spot-list'}).findAll('a', attrs={'class':'country'})
locations = soup.find('div', attrs={'class':'block spot-list'}).findAll('a')

# %%
coords = []
# for country in countries:
#     # print(country.text)
#     curl = country.attrs['href']
#     creq = requests.get(curl)
#     csoup = BeautifulSoup(creq.content, 'html.parser')
    
#     spots = []
#     regions = csoup.find('div', attrs={'class':'block spot-list'})
#     # check if the country was broken down into regions
#     if regions:
#         for region in regions.findAll('a', attrs={'class':'country'}):
#             # print(region)
#             rurl = region.attrs['href']
#             rreq = requests.get(rurl)
#             rsoup = BeautifulSoup(rreq.content, 'html.parser')
            
#             # attempt to grab all spots for the region
#             try:
#                 regional_spots = rsoup.find('table', attrs={'class':'spotTable'}).findAll('a')
#                 spots.extend(regional_spots)
#             except AttributeError as e:
#                 print(f'{region.text} has no spots')
#                 continue
#     else:
#         # attempt to grab all spots for the country
#         try:
#             regional_spots = csoup.find('table', attrs={'class':'spotTable'}).findAll('a')
#             spots.extend(regional_spots)
#         except AttributeError as e:
#             print(f'{country.text} has no spots')
#             continue
    
    # find the latitude and longitude of each location by parsing the marker URL
